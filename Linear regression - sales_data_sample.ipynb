# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Part 1 - Data Preprocessing

# %% [markdown]
# - Importing the dataset

# %%
# using ISO-8859-1 for specific file importing
import pandas as pd
data = pd.read_csv('sales_data_sample.csv', encoding='ISO-8859-1')
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %% [markdown]
# - HANDLE MISSING VALUES

# %%
data.isnull().sum()
# identifying missing values in the dataset
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
data.dropna(axis = 1, inplace= True)
data.isnull().sum()
# dropping missing category values
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %% [markdown]
# - Check for outliers and handle them

# %%
# The Z-score is a useful tool for handling outliers
import numpy as np
numeric_columns = data.select_dtypes(include= [np.number]).columns
z_scores= np.abs((data[numeric_columns] - data[numeric_columns].mean()) / data[numeric_columns].std())
z_scores

data = data[(z_scores < 3).all(axis = 1)]

# %% [markdown]
# ### Getting the inputs and output

# %%
#  Convert the 'STATUS' column to numerical values 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['STATUS'] = le.fit_transform(data['STATUS'])
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... MSRP  \
# 0      2/24/2003 0:00       5       1         2     2003  ...   95
# 1       5/7/2003 0:00       5       2         5     2003  ...   95
# 2       7/1/2003 0:00       5       3         7     2003  ...   95
# 3      8/25/2003 0:00       5       3         8     2003  ...   95
# 4     10/10/2003 0:00       5       4        10     2003  ...   95
# ...               ...     ...     ...       ...      ...  ...  ...
# 2818   12/2/2004 0:00       5       4        12     2004  ...   54
# 2819   1/31/2005 0:00       5       1         1     2005  ...   54
# 2820    3/1/2005 0:00       4       1         3     2005  ...   54
# 2821   3/28/2005 0:00       5       1         3     2005  ...   54
# 2822    5/6/2005 0:00       3       2         5     2005  ...   54
#
#       PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0        S10_1678         Land of Toys Inc.        2125557818
# 1        S10_1678        Reims Collectables        26.47.1555
# 2        S10_1678           Lyon Souveniers  +33 1 46 62 7555
# 3        S10_1678         Toys4GrownUps.com        6265557265
# 4        S10_1678  Corporate Gift Ideas Co.        6505551386
# ...           ...                       ...               ...
# 2818     S72_3212     Euro Shopping Channel    (91) 555 94 44
# 2819     S72_3212   Oulu Toy Supplies, Inc.        981-443655
# 2820     S72_3212     Euro Shopping Channel    (91) 555 94 44
# 2821     S72_3212              Alpha Cognac        61.77.6555
# 2822     S72_3212         Gifts4AllAges.com        6175559555
#
#                        ADDRESSLINE1           CITY  COUNTRY CONTACTLASTNAME  \
# 0           897 Long Airport Avenue            NYC      USA              Yu
# 1                59 rue de l'Abbaye          Reims   France         Henriot
# 2     27 rue du Colonel Pierre Avia          Paris   France        Da Cunha
# 3                78934 Hillside Dr.       Pasadena      USA           Young
# 4                   7734 Strong St.  San Francisco      USA           Brown
# ...                             ...            ...      ...             ...
# 2818             C/ Moralzarzal, 86         Madrid    Spain          Freyre
# 2819                    Torikatu 38           Oulu  Finland       Koskitalo
# 2820             C/ Moralzarzal, 86         Madrid    Spain          Freyre
# 2821          1 rue Alsace-Lorraine       Toulouse   France          Roulet
# 2822             8616 Spinnaker Dr.         Boston      USA         Yoshido
#
#      CONTACTFIRSTNAME DEALSIZE
# 0                Kwai    Small
# 1                Paul    Small
# 2              Daniel   Medium
# 3               Julie   Medium
# 4               Julie   Medium
# ...               ...      ...
# 2818            Diego    Small
# 2819           Pirkko   Medium
# 2820            Diego   Medium
# 2821          Annette    Small
# 2822             Juri   Medium
#
# [2784 rows x 21 columns]

# %%
# Selecting relevant features and the target variable
X_features = ['QUANTITYORDERED', 'PRICEEACH', 'MSRP','STATUS']
y_features = 'SALES'
X = data[X_features]
y = data[y_features]

# %%
X
# Independent Variables
# Out:
#       QUANTITYORDERED  PRICEEACH  MSRP  STATUS
# 0                  30      95.70    95       5
# 1                  34      81.35    95       5
# 2                  41      94.74    95       5
# 3                  45      83.26    95       5
# 4                  49     100.00    95       5
# ...               ...        ...   ...     ...
# 2818               20     100.00    54       5
# 2819               29     100.00    54       5
# 2820               43     100.00    54       4
# 2821               34      62.24    54       5
# 2822               47      65.52    54       3
#
# [2784 rows x 4 columns]

# %%
y
# Dependent Variable
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       5205.27
#          ...
# 2818    2244.40
# 2819    3978.51
# 2820    5417.57
# 2821    2116.16
# 2822    3079.44
# Name: SALES, Length: 2784, dtype: float64

# %% [markdown]
# - Creating the Training Set and the Test Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,  y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0)

# %%
X_train
# Out:
#       QUANTITYORDERED  PRICEEACH  MSRP  STATUS
# 1312               28      58.58    87       5
# 456                42     100.00   141       5
# 2006               48      56.64    68       5
# 1847               31      73.62    85       5
# 2691               39      81.14   100       5
# ...               ...        ...   ...     ...
# 785                21      70.96    84       5
# 858                37     100.00   132       5
# 1683               33      66.49    69       5
# 2645               36     100.00   118       5
# 2771               28      48.17    49       5
#
# [2227 rows x 4 columns]

# %%
X_test
# Out:
#       QUANTITYORDERED  PRICEEACH  MSRP  STATUS
# 1459               48      47.40    57       5
# 584                44     100.00   170       5
# 113                26     100.00   136       5
# 2092               39     100.00    97       5
# 312                34      96.73   117       5
# ...               ...        ...   ...     ...
# 1248               39     100.00   143       5
# 1787               24      87.24   117       5
# 1543               37      27.22    33       5
# 2341               26     100.00   102       5
# 506                45      51.21    53       5
#
# [557 rows x 4 columns]

# %%
y_train
# Out:
# 1312    1640.24
# 456     6182.40
# 2006    2718.72
# 1847    2282.22
# 2691    3164.46
#          ...
# 785     1490.16
# 858     4346.76
# 1683    2194.17
# 2645    4527.72
# 2771    1348.76
# Name: SALES, Length: 2227, dtype: float64

# %%
y_train
# Out:
# 1312    1640.24
# 456     6182.40
# 2006    2718.72
# 1847    2282.22
# 2691    3164.46
#          ...
# 785     1490.16
# 858     4346.76
# 1683    2194.17
# 2645    4527.72
# 2771    1348.76
# Name: SALES, Length: 2227, dtype: float64

# %% [markdown]
# ## Part 2 - Building and training the model

# %% [markdown]
# ### Building the model

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()

# %% [markdown]
# ### Training the Model

# %%
from sklearn.preprocessing import StandardScaler

# Normalize if necessary
scaler = StandardScaler()
X_train_Scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# fit is a method inside LinearRegression class - they are like functions
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Inference

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([2736.96070072, 6003.02068787, 3784.93507231, 4485.61942713,
#        4159.62372878, 4942.28761014, 2454.7233481 , 4309.56390302,
#        4431.72063061, 4431.72063061, 6780.25738846, 1979.3423098 ,
#        4641.54838023, 1960.46219801, 3076.14567907, 4116.7411795 ,
#        2445.37183908, 2079.98620998, 4264.37571789, 3963.42063312,
#        6334.82679506, 5540.76343839, 4577.51692008, 3433.24022078,
#        -818.41537595, 2959.70689429, 5949.12189134, 4049.82854514,
#        5172.29615377, 3810.28896483, 4569.33938852, 2450.64199348,
#        4199.12041841, 3392.62823654,  769.80351833, 2297.91375486,
#        4434.48543551, 4167.9346278 , 1724.69874055, 3287.08423217,
#        3981.79271464, 5418.78508082, 1198.17461828, 2994.29657035,
#        1626.3906233 , 1268.31122658, 6916.29759721, 5699.51665305,
#        2665.67237803, 3217.01015402, 1215.999172  , 2372.48461999,
#        4460.08215966, 4461.32146513,  743.93929162, 4136.61674174,
#        5588.89479843, 2392.822846  , 3016.29006977,  939.07927599,
#        3004.99302349, 3695.22427062, 4729.51668561, 2829.198725  ,
#        3800.56037471, 5515.22617091, 2173.49718342, 2183.03256559,
#        5520.81523738, 1820.03784814, 1716.00947279, 4713.43347055,
#        4831.66575552, 4190.58817703, 6088.16473168, 3952.54811579,
#        4139.51364208, 2378.50230707, 5756.18025448, 4264.25680455,
#        4048.72107512, 3997.64654017, 4586.10605848, 1875.73027486,
#        3246.12547707, 1478.25853336, 3805.2822275 , 2494.58651202,
#        3372.84510908, 2928.44067773, 2158.17862302, 4743.69745014,
#        2831.99958763, 5807.3142461 , 1510.20119146, 3529.68131088,
#        1055.50347666, 4258.66773808, 2909.44457621,  185.28571023,
#        1429.11841503,  526.33859776, 3920.80008328, 1757.30990124,
#        3298.27347013, 4953.12738758, 5187.20795103, 2553.97336362,
#        3511.63976028, 3380.55872664, 4655.72914475, 2059.25289887,
#        1644.6191049 , 2074.86798443, 1499.56305297, 2344.1908704 ,
#        4556.52324975, 5949.06243467, 1827.6113231 , 2744.91446026,
#        1598.49709991, 3055.34586051,  800.18068129, 5317.76356817,
#        5427.25786553, 1552.99154418,  864.9756399 , 3255.24783477,
#        2609.2452169 , 3314.61855463, 1689.28889305, 4947.87667661,
#        3090.364541  , 2634.95844036, 3810.7104203 , 6142.00407154,
#        1552.99154418, 5469.68124576,  622.55387   , 3597.76087193,
#        2146.4143449 , 3065.40704301, 2610.31125604, 1305.1207394 ,
#        2212.84028836, 3861.60633141, 2844.69718126, 2874.48242453,
#        4661.37766789, 5291.09874343, 4267.08106612, 1972.4431048 ,
#        3373.63344444, 2006.29060569, 3320.56911792, -565.20229183,
#        2512.67037552, 5234.37568533, 3878.11969293, 1449.25586232,
#        2622.03591091, 4942.1686968 , 3462.37522547, 5057.32659345,
#        1384.31973491, 2874.97688697, 4772.05897918, 4513.98095618,
#        1619.97437202, 3877.30349877, 5458.50311282, 2247.45108547,
#        1579.29002463, 2129.88218377, 2426.34648291, 3022.40492094,
#        1280.75156195, 4338.04434541, 4079.96632241, 1484.01779268,
#        3336.79913068, 5415.96081924, 3668.26240689, 1077.40362187,
#         554.41433846, 4773.3485422 , 1265.26448063, 4369.2895927 ,
#        3376.57661935, 2998.32664546, 3737.43577328, 3750.34793748,
#        5137.93459524, 2825.46403303,  549.51844552, 3302.78907849,
#        2539.35935739])

# %%
y_test
# Out:
# 1459    2275.20
# 584     7554.80
# 113     3854.24
# 2092    4424.16
# 312     3288.82
#          ...
# 1248    5096.91
# 1787    2093.76
# 1543    1007.14
# 2341    2600.26
# 506     2304.45
# Name: SALES, Length: 557, dtype: float64

# %% [markdown]
# ## Part 3: Evaluating the Model

# %% [markdown]
# ### R-Squared

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8101270573704877

# %% [markdown]
# ### Adjusted R-Squared

# %%
k = X_test.shape[1]
k
# Out:
# 4

# %%
n = X_test.shape[0]
n
# Out:
# 557

# %%
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
adj_r2
# Out:
# 0.8087511664818681

# %% [markdown]
# ### ERROR MEANS SQUARED

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_pred, y_test)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 533303.0383686159

# %% [markdown]
# ### Getting the coefficients of the model

# %%
# Coefficients of the model
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
coefficients

# Interpretation:
# Higher coefficients indicate stronger relationships with the target variable (Sales).
# Out:
#                  Coefficient
# QUANTITYORDERED    96.441090
# PRICEEACH          38.961938
# MSRP               14.180765
# STATUS             24.881167

# %% [markdown]
# ### VISUALIZATION

# %%
# Scatter plot to compare true vs predicted values
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.show()
